# %% [markdown]
# # Monitoring with alibi_detect

# %% [markdown]
# If needed install:

# %%
# !which python3
# !pip install matplotlib
# Out:
# /usr/local/bin/python3
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install ipython
# Out:
# Requirement already satisfied: ipython in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (9.1.0)
# Requirement already satisfied: decorator in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from ipython) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack_data in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from stack_data->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from stack_data->ipython) (0.2.3)

# %%
# !pip install seaborn~=0.13.2
# Out:
# Requirement already satisfied: seaborn~=0.13.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seaborn~=0.13.2) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seaborn~=0.13.2) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from seaborn~=0.13.2) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn~=0.13.2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn~=0.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn~=0.13.2) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn~=0.13.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn~=0.13.2) (24.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn~=0.13.2) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn~=0.13.2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn~=0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.2->seaborn~=0.13.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.2->seaborn~=0.13.2) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/mahamatabakarassouna/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn~=0.13.2) (1.17.0)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Illustrating the need to monitor metrics at various window sizes to catch performance degradation as soon as possible.
#
# Imagine we are logging/saving the F1 metrics every day fo 35 days. To mimic this, we will output random numbers in predefined intervals for every hour of the 35 days.
#
# - For the first 20 days we will use the interval [94, 98)
# - For the next 5 days we will use the interval [92, 96)
# - For the next 5 days we will use the interval [88, 96)
# - For the last 5 days we will use the interval [86, 92)
#
# Please note how the interval for random generating changes, this is how we mimic a drift in the data.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/mahamatabakarassouna/Library/Python/3.12/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mahamatabakarassouna/Library/Python/3.12/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/mahamatabakarassouna/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme()

# Generate data
hourly_f1 = list(np.random.randint(low=94, high=98, size=24*20)) + \
            list(np.random.randint(low=92, high=96, size=24*5)) + \
            list(np.random.randint(low=88, high=96, size=24*5)) + \
            list(np.random.randint(low=86, high=92, size=24*5))

# %%
hourly_f1 = np.array(hourly_f1)

# %% [markdown]
# ##### **TODO:** Compute the **cumulative mean** of the F1 values given in `hourly_f1`.
#
# For example for an array `[3, 1, 2, 10]` a cumulative mean array would be: `[3, 2, 2, 4]`.
#
# Explanation:
# - at iteration 0: we use the element at 0th position in original array to calculate the mean --> 3/1=3
# - at iteration 1: we use the elements at 0th and 1st position in original array to calculate the mean --> (3+1)/2=2
# - at iteration 2: we use the elements at 0th, 1st and 2nd position in original array to calculate the mean --> (3+1+2)/3=2
# - at iteration 3: we use the elements at 0th and up to 3rd position in original array to calculate the mean --> (3+1+2+10)/4=4

# %%
c_means =[]
for i in range(0, len(hourly_f1)):
    c_mean = np.mean(hourly_f1[:i+1])
    c_means.append(c_mean)
c_means = np.array(c_means)
# print(c_means)

# %% [markdown]
# ##### **TODO:** Print the average cumulative F1 on the last day.

# %%
avg_f1 = np.mean(c_means[-24:])
print(avg_f1)
# Out:
# 93.72678105927541

# %% [markdown]
# ##### **TODO:** Calculate the **daily sliding F1** of the values given in `hourly_f1`.
#
# For example for an array [ 4,  2,  3,  8, -6, 10] a sliding average with a window of size 3 would be: [3, 4.33, 1.667, 4].
#
# Explanation:
#
# - at iteration 0: we use the first 3 elements to calculate the mean --> (4+2+3)/3=3
# - at iteration 1: we use the elements at 1st,2nd,3rd position in original array to calculate the mean --> (2+3+8)/3=4.333
# - at iteration 2: we use the elements at 2nd,3rd,4th position in original array to calculate the mean --> (3+8-6)/3=1.667
# - at iteration 3: we use the elements at 3rd,4th,5th position in original array to calculate the mean --> (8-6+10)/3=4

# %%
sliding_avg = []
window_size = 24
for i in range(len(hourly_f1) - window_size + 1):
    window = hourly_f1[i:i + window_size]
    window_avg = np.mean(window)
    sliding_avg.append(window_avg)
sliding_avg = np.array(sliding_avg)
# print(sliding_avg)

# %% [markdown]
# ##### **TODO:** Print the average sliding F1 on the last day.

# %%
mean_sliding_avg = np.mean(sliding_avg[-24:])
print(mean_sliding_avg)
# Out:
# 88.06597222222221

# %% [markdown]
# ##### **TODO:** Plot the cumulative and sliding values on a graph.
#
# - Y-axes can be limited to `[80,100]`.
#
# - Optionally, add a threshold line at `y=90`

# %%
plt.figure(figsize=(15, 5))
plt.plot(c_means, label='Cumulative mean', color='blue', alpha=0.5)
plt.plot(sliding_avg, label='sliding', color='orange', linewidth=2)
plt.ylim(80, 100)
plt.hlines(y = 90, xmin=0, xmax=len(hourly_f1), colors="green", linestyles= "dashdot", label='Threshold')
plt.legend()
plt.title('Hourly F1 Score Monitoring')
# Out:
# Text(0.5, 1.0, 'Hourly F1 Score Monitoring')

# %% [markdown]
# ## Data

# %%
import json
import pandas as pd

# %% [markdown]
# ##### **TODO:**
# 1. Read the `projects` and `tags` files and join them into a `combined` dataframe.
# 2. Create a new column called `text` where you will place the `title` and `description` joined with a space character -- `{title} {description}`.
# 3. Drop the `title` and `description` columns.

# %%
# 1. Read the files
projects = pd.read_csv("projects.csv")
tags = pd.read_csv("tags.csv")

# Join on a common key (adjust "project_id" to whatever column they share)
combined = pd.merge(projects,tags)

# 2. Create the new column "text"
combined["text"] = combined["title"] + " " + combined["description"]

# 3. Drop the original columns
combined = combined.drop(columns=["title", "description"])

# Show result
print(combined.head())
# Out:
#    id           created_on                     tag  \
# 0   6  2020-02-20 06:43:18         computer-vision
# 1   7  2020-02-20 06:47:21          graph-learning
# 2   9  2020-02-24 16:24:45  reinforcement-learning
# 3  15  2020-02-28 23:55:26          graph-learning
# 4  25  2020-03-07 23:04:31          graph-learning
#
#                                                 text
# 0  Comparison between YOLO and RCNN on real world...
# 1  Show, Infer & Tell: Contextual Inference for C...
# 2  Awesome Graph Classification A collection of i...
# 3  Awesome Monte Carlo Tree Search A curated list...
# 4  AttentionWalk A PyTorch Implementation of "Wat...

# %% [markdown]
# We will use this dataframe as our reference/original data, data that we used to train our ML models. Not to be mistaken with the "real-world" data received in prod

# %% [markdown]
# ## Univariate

# %% [markdown]
# Drift detection on univariate data.

# %% [markdown]
# ### Kolmogorov-Smirnov (KS) test
#
# KS test for detecting data drift on input sequence length. We can even monitor aspects of our data that aren't necessarily inputs to the model (ex. length of input text).

# %%
# !pip install alibi_detect --upgrade
# !pip install pyOpenSSL==22.0.0
# Out:
# Collecting alibi_detect
#   Using cached alibi_detect-0.12.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from alibi_detect) (3.10.1)
# Collecting numpy<2.0.0,>=1.16.2 (from alibi_detect)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from alibi_detect) (2.2.3)
# Collecting Pillow<11.0.0,>=5.4.1 (from alibi_detect)
#   Using cached pillow-10.4.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting opencv-python<5.0.0,>=3.2.0 (from alibi_detect)
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from alibi_detect) (1.15.3)
# Collecting scikit-image<0.23,>=0.19 (from alibi_detect)
#   Using cached scikit_image-0.22.0.tar.gz (22.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [10 lines of output]
#       + meson setup /private/var/folders/c6/1npg_m3n3qz9mc8qxyh2_2600000gn/T/pip-install-m4vo8yzf/scikit-image_1e7f3e57050f4b01894132dbb8146ffa /private/var/folders/c6/1npg_m3n3qz9mc8qxyh2_2600000gn/T/pip-install-m4vo8yzf/scikit-image_1e7f3e57050f4b01894132dbb8146ffa/.mesonpy-l_i3e3ol -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=/private/var/folders/c6/1npg_m3n3qz9mc8qxyh2_2600000gn/T/pip-install-m4vo8yzf/scikit-image_1e7f3e57050f4b01894132dbb8146ffa/.mesonpy-l_i3e3ol/meson-python-native-file.ini
#       The Meson build system
#       Version: 1.9.1
#       Source dir: /private/var/folders/c6/1npg_m3n3qz9mc8qxyh2_2600000gn/T/pip-install-m4vo8yzf/scikit-image_1e7f3e57050f4b01894132dbb8146ffa
#       Build dir: /private/var/folders/c6/1npg_m3n3qz9mc8qxyh2_2600000gn/T/pip-install-m4vo8yzf/scikit-image_1e7f3e57050f4b01894132dbb8146ffa/.mesonpy-l_i3e3ol
#       Build type: native build
#
#       ../meson.build:7:11: ERROR: Command `/private/var/folders/c6/1npg_m3n3qz9mc8qxyh2_2600000gn/T/pip-install-m4vo8yzf/scikit-image_1e7f3e57050f4b01894132dbb8146ffa/skimage/_build_utils/version.py` failed with status 127.
#
#       A full log can be found at /private/var/folders/c6/1npg_m3n3qz9mc8qxyh2_2600000gn/T/pip-install-m4vo8yzf/scikit-image_1e7f3e57050f4b01894132dbb8146ffa/.mesonpy-l_i3e3ol/meson-logs/meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: pyOpenSSL==22.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (22.0.0)
# Requirement already satisfied: cryptography>=35.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyOpenSSL==22.0.0) (45.0.7)
# Requirement already satisfied: cffi>=1.14 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography>=35.0->pyOpenSSL==22.0.0) (1.17.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=35.0->pyOpenSSL==22.0.0) (2.22)

# %% [markdown]
# ##### **TODO**:
# 1. Create a new column that will hold the number of words (e.g., separated by " ") in the `text` column
# 2. Plot a histogram for the first 200 rows of the newly created column from original dataframe

# %%
import matplotlib.pyplot as plt
# 1. Create column with word counts
combined["word_count"] = combined["text"].apply(lambda x: len(str(x).split()))

# 2. Take first 200 rows and plot histogram
subset = combined.head(200)

plt.hist(subset["word_count"], bins=20, edgecolor="black")
plt.xlabel("Word Count")
plt.ylabel("Frequency")
plt.title("Histogram of first 200 rows")
plt.show()

# %% [markdown]
# ##### **TODO:** Initialize the KSDrift detector on the reference data.

# %%
pip install alibi-detect
# Out:
# Requirement already satisfied: alibi-detect in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.12.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (3.10.6)
# Requirement already satisfied: numpy<2.0.0,>=1.16.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (2.3.3)
# Requirement already satisfied: Pillow<11.0.0,>=5.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (10.4.0)
# Requirement already satisfied: opencv-python<5.0.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (4.11.0.86)
# Requirement already satisfied: scipy<2.0.0,>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (1.16.2)
# Requirement already satisfied: scikit-image<0.23,>=0.19 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (0.22.0)
# Requirement already satisfied: scikit-learn<2.0.0,>=0.20.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (1.7.2)
# Requirement already satisfied: transformers<5.0.0,>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (4.56.2)
# Requirement already satisfied: dill<0.4.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (0.3.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.28.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (2.11.9)
# Requirement already satisfied: toml<1.0.0,>=0.10.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (0.10.2)
# Requirement already satisfied: catalogue<3.0.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (2.0.10)
# Requirement already satisfied: numba!=0.54.0,<0.60.0,>=0.50.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (0.59.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from alibi-detect) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/mahamatabakarassouna/Library/Python/3.12/lib/python/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mahamatabakarassouna/Library/Python/3.12/lib/python/site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from numba!=0.54.0,<0.60.0,>=0.50.0->alibi-detect) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas<3.0.0,>=1.0.0->alibi-detect) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas<3.0.0,>=1.0.0->alibi-detect) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=1.8.0->alibi-detect) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=1.8.0->alibi-detect) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0.0,>=1.8.0->alibi-detect) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (2025.8.3)
# Requirement already satisfied: networkx>=2.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-image<0.23,>=0.19->alibi-detect) (3.5)
# Requirement already satisfied: imageio>=2.27 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-image<0.23,>=0.19->alibi-detect) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-image<0.23,>=0.19->alibi-detect) (2025.9.30)
# Requirement already satisfied: lazy_loader>=0.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-image<0.23,>=0.19->alibi-detect) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn<2.0.0,>=0.20.2->alibi-detect) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn<2.0.0,>=0.20.2->alibi-detect) (3.6.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (0.35.3)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (2025.9.18)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0,>=4.0.0->alibi-detect) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0,>=4.0.0->alibi-detect) (1.1.10)
# Requirement already satisfied: six>=1.5 in /Users/mahamatabakarassouna/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.0->alibi-detect) (1.17.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from alibi_detect.cd import KSDrift
import numpy as np

combined["num_words"] = combined.text.apply(lambda x: len(x.split(" ")))

# Generate reference data (e.g. 1000 samples, 10 features)
X_ref = combined["word_count"][0:200].to_numpy()  # Using word_count as a feature
# Initialize the KSDrift detector, p_val: significance level, usually 0.05 
length_drift_detector = KSDrift(X_ref, p_val=0.05)

# %% [markdown]
# ##### **TODO:**
# 1. Plot a histogram for the first 200 rows from original dataframe (same as previous task).
# 2. On top of it, plot a histogram for the next 200 rows (i.e., `[200,400)`) from original dataframe

# %%
#1. Plot a histogram for the first 200 rows from original dataframe (same as previous task).
plt.hist(subset["word_count"], bins=20, edgecolor="black")
plt.xlabel("Word Count")
plt.ylabel("Frequency")
plt.title("Histogram of first 200 rows")

#2. On top of it, plot a histogram for the next 200 rows (i.e., `[200,400)`) from original dataframe
No_drift = combined.iloc[200:400]
plt.hist(No_drift["word_count"], bins=20, edgecolor="black", alpha=0.7, color='orange')
plt.xlabel("Word Count")
plt.ylabel("Frequency")
plt.title("Histogram of first 400 rows")
plt.show()

# %% [markdown]
# ##### **TODO:** Apply the drift detector.

# %%
# Apply the drift detector
preds = length_drift_detector.predict(No_drift["word_count"].values.reshape(-1, 1))
print(preds)
# Out:
# {'data': {'is_drift': 0, 'distance': array([0.105], dtype=float32), 'p_val': array([0.20524779], dtype=float32), 'threshold': 0.05}, 'meta': {'name': 'KSDrift', 'online': False, 'data_type': None, 'version': '0.12.0', 'detector_type': 'drift'}}

# %% [markdown]
# Given that both dataframes are actually part of the same data, there is no noticeble drift to be detected.

# %% [markdown]
# ##### **TODO:**
# 1. Create new data (to represent production data) from a normal distribution with mean=30 and std=5; you can create 200 examples.
# 2. Plot a hist of this data on top of the hist of the reference data (first 200 rows).

# %%
New_data = np.random.normal(30, 5, len(X_ref))

# %%
plt.hist(X_ref, alpha=0.75, label="reference")
plt.hist(New_data, alpha=0.5, label="test_data")
plt.legend()
plt.show()

# %% [markdown]
# ##### **TODO:** Apply the drift detector to the reference data and the normal distributed (production) data.

# %%
length_drift_detector = KSDrift(New_data, p_val=0.05)
#print(length_drift_detector)
length_drift_detector = length_drift_detector.predict(combined["word_count"].values.reshape(-1, 1))
length_drift_detector
# Out:
# {'data': {'is_drift': 1,
#   'distance': array([0.59159684], dtype=float32),
#   'p_val': array([0.], dtype=float32),
#   'threshold': 0.05},
#  'meta': {'name': 'KSDrift',
#   'online': False,
#   'data_type': None,
#   'version': '0.12.0',
#   'detector_type': 'drift'}}

# %% [markdown]
# ### Chi-squared test

# %% [markdown]
# Detecting drift on categorical variables (can be used for data or target drift).

# %%
from alibi_detect.cd import ChiSquareDrift
import numpy as np
combined["num_words"] = combined.text.apply(lambda x: len(x.split(" ")))

# %% [markdown]
# ##### **TODO:**
# 1. Add a new column to the reference data called `token_count`. This column should have the value `small` if the `num_tokens` is less or equal than 10; `medium` if in between (10,25] and `large` if larger than 25.
# 2. Plot the first 200 data of reference data as a histogram.

# %%
#1.Add a new column to the reference data called `token_count`. This column should have the value `small` if the `num_tokens` is less or equal than 10; `medium` if in between (10,25] and `large` if larger than 25.
def categorize_token_count(num_tokens):
    if num_tokens <= 10:
        return 'small'
    elif 10 < num_tokens <= 25:
        return 'medium'
    else:
        return 'large'
combined['token_count'] = combined['num_words'].apply(categorize_token_count)
#2. Plot the first 200 data of reference data as a histogram.
plt.hist(combined['token_count'][0:200], bins=10, edgecolor='black')
plt.xlabel("Token Count Category")
plt.ylabel("Frequency")
plt.title("Histogram of Token Count Categories (first 200 rows)")
plt.show()

# %% [markdown]
# ##### **TODO:** Initialize the drift detector

# %%
#2. Initialize the ChiSquareDrift detector using the `token_count` column as reference data.
X_ref = combined["token_count"][0:200].to_numpy().reshape(-1, 1)  # Using token_count as a feature
chi2_drift_detector = ChiSquareDrift(X_ref, p_val=0.05)

# %% [markdown]
# ##### **TODO:**
# 1. Take the next 200 data rows from original data, and plot it over the reference data (first 200 rows).
# 2. Apply the drift detector.

# %%
No_drift = combined.iloc[200:400]
preds = chi2_drift_detector.predict(No_drift["token_count"].values.reshape(-1, 1))
print(preds)
# Out:
# {'data': {'is_drift': 1, 'distance': array([7.497912], dtype=float32), 'p_val': array([0.02354231], dtype=float32), 'threshold': 0.05}, 'meta': {'name': 'ChiSquareDrift', 'online': False, 'data_type': None, 'version': '0.12.0', 'detector_type': 'drift'}}

# %% [markdown]
# ##### **TODO:**
# 1. Create production data, where you have 80 times `small`, 40 times `medium` and 80 times `large`.
# 2. Plot the histogram of productions data on top of reference data (first 200 rows).
# 3. Apply drift detector.

# %%
#1. Create production data, where you have 80 times `small`, 40 times `medium` and 80 times `large`.
New_data = np.array(['small']*80 + ['medium']*40 + ['large']*80).reshape(-1, 1)

#2. Plot the histogram of productions data on top of reference data (first 200 rows).
plt.hist(combined['token_count'][0:200], alpha=0.75, label="reference")
plt.hist(New_data, alpha=0.5, label="test_data")
plt.legend()
plt.show()

# %%
#3. Apply drift detector.
chi2_drift_detector = ChiSquareDrift(New_data, p_val=0.05)
chi2_drift_detector = chi2_drift_detector.predict(New_data)
chi2_drift_detector
# Out:
# {'data': {'is_drift': 0,
#   'distance': array([0.], dtype=float32),
#   'p_val': array([1.], dtype=float32),
#   'threshold': 0.05},
#  'meta': {'name': 'ChiSquareDrift',
#   'online': False,
#   'data_type': None,
#   'version': '0.12.0',
#   'detector_type': 'drift'}}
